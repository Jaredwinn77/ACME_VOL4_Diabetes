# %%
from model import *
import matplotlib.pyplot as plt

# %%
spikes = spike()
t_steps = 1440
dt = 5
starting = np.array([150, 15])
a = 0.1
b = 0.01
c = 0.05
d = 0.0
glucose_penalty = 10
insulin_penalty = 10
controller_penalty = 30
derivitive_penalty = 20
step_delay = 3
t, states = simulate(spikes, 
                     t_steps, 
                     dt, 
                     starting, 
                     a, 
                     b, 
                     c, 
                     d, 
                     glucose_penalty, 
                     insulin_penalty, 
                     controller_penalty, 
                     derivitive_penalty, 
                     target=83, 
                     base_insulin=10, 
                     step_delay=step_delay)

plt.plot(t, states[0], label='glucose')
plt.plot(t, states[1], label='insulin')
plt.legend()
plt.show()
